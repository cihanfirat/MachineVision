# %%
import os

base_dir = "data_resized"

for class_name in os.listdir(base_dir):
    class_path = os.path.join(base_dir, class_name)

    if not os.path.isdir(class_path):
        continue

    files = os.listdir(class_path)
    files.sort()  # sıralı olsun diye

    for i, filename in enumerate(files, start=1):
        old_path = os.path.join(class_path, filename)

        ext = os.path.splitext(filename)[1]  # .jpg, .png vs
        new_name = f"{class_name}_{i}{ext}"
        new_path = os.path.join(class_path, new_name)

        os.rename(old_path, new_path)

    print(f"{class_name} klasörü tamamlandı.")
# Out:
# cam klasörü tamamlandı.
# kagit klasörü tamamlandı.
# metal klasörü tamamlandı.
# pil klasörü tamamlandı.
# plastik klasörü tamamlandı.
